# %% [markdown]
# ##### 1 -> Fake news
# ##### 0 -> Real news

# %%
import pandas as pd
import numpy as np
import re # Regular expressions module used for string matching 
from nltk.corpus import stopwords
